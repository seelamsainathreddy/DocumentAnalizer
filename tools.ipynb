# %%
from openai import OpenAI
client = OpenAI()

# %%
assistant = client.beta.assistants.create(
  name="Data visualizer",
  description="You are great at creating beautiful data visualizations. You analyze data present in .csv files, understand trends, and come up with data visualizations relevant to those trends. You also share a brief text summary of the trends observed.",
  model="gpt-4o",
  tools=[{"type": "code_interpreter"}],
  tool_resources={
    "code_interpreter": {
      "file_ids": [file.id]
    }
  }
)

# %%
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": "Create 3 data visualizations based on the trends in this file.",
      "attachments": [
        {
          "file_id": file.id,
          "tools": [{"type": "code_interpreter"}]
        }
      ]
    }
  ]
)

# %%
file = client.files.create(
  file=open("myimage.jpg", "rb"),
  purpose="vision"
)
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "What is the difference between these images?"
        },
        {
          "type": "image_url",
          "image_url": {"url": "https://pynr.in/wp-content/uploads/2024/07/Second-6-1068x713.jpg"}
        },
        {
          "type": "image_file",
          "image_file": {"file_id": file.id}
        },
      ],
    }
  ]
)

# %%
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "What is this an image of?"
        },
        {
          "type": "image_file",
          "image_file": {"file_id": file.id}
        },
      ],
    }
  ]
)

# %%
from typing_extensions import override
from openai import AssistantEventHandler
 
# First, we create a EventHandler class to define
# how we want to handle the events in the response stream.
 
class EventHandler(AssistantEventHandler):    
  @override
  def on_text_created(self, text) -> None:
    print(f"\nassistant > ", end="", flush=True)
      
  @override
  def on_text_delta(self, delta, snapshot):
    print(delta.value, end="", flush=True)
      
  def on_tool_call_created(self, tool_call):
    print(f"\nassistant > {tool_call.type}\n", flush=True)
  
  def on_tool_call_delta(self, delta, snapshot):
    if delta.type == 'code_interpreter':
      if delta.code_interpreter.input:
        print(delta.code_interpreter.input, end="", flush=True)
      if delta.code_interpreter.outputs:
        print(f"\n\noutput >", flush=True)
        for output in delta.code_interpreter.outputs:
          if output.type == "logs":
            print(f"\n{output.logs}", flush=True)
 
# Then, we use the `stream` SDK helper 
# with the `EventHandler` class to create the Run 
# and stream the response.
 
with client.beta.threads.runs.stream(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions="Please address the user as Jane Doe. The user has a premium account.",
  event_handler=EventHandler(),
) as stream:
  stream.until_done()
# Out:
# assistant > This is an image of a man playing an electric guitar, likely performing a musical act on stage. The lighting is vibrant, with colorful stage lights illuminating the scene, and the guitarist has a happy expression, suggesting he is enjoying the performance.

# %%
file = client.files.create(
  file=open("revenue-forecast.csv", "rb"),
  purpose='assistants'
)

# %%
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": "Create 3 data visualizations based on the trends in this file.",
      "attachments": [
        {
          "file_id": file.id,
          "tools": [{"type": "code_interpreter"}]
        }
      ]
    }
  ]
)

# %%
with client.beta.threads.runs.stream(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions="Please address the user as Jane Doe. The user has a premium account.",
  event_handler=EventHandler(),
) as stream:
  stream.until_done()
# Out:
# assistant > Jane Doe, I'll first take a look at the contents of the uploaded files to understand the data and then create three data visualizations based on it. Let's start by examining the first file.
# assistant > code_interpreter
#
# import pandas as pd
#
# # Load and examine the first few rows of the first file
# file_path_1 = '/mnt/data/file-MKPDZvsfxVSykKVzbAX887oq'
# data_1 = pd.read_csv(file_path_1)
# data_1.head()
# assistant > The first file contains data on monthly sales, revenue, cost, and profit forecasts for different products. The columns include:
#
# - Month
# - Product
# - Sales Forecast
# - Revenue Forecast
# - Cost Forecast
# - Profit Forecast
#
# Let's now examine the second file to see if it provides additional data or context.# Load and examine the first few rows of the second file
# file_path_2 = '/mnt/data/file-9LohmXkuu5YXY6imeO8jbVuu'
# data_2 = pd.read_csv(file_path_2)
# data_2.head()
# assistant > Both files appear to contain identical data, providing sales, revenue, cost, and profit forecasts for different products over several months. I'll create three visualizations based on these trends:
#
# 1. Sales Forecast Trend Over Time for Each Product.
# 2. Revenue Vs. Cost Forecast for Each Product.
# 3. Profit Forecast Comparison Between Products.
#
# Let's create these visualizations.import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Set up the visual style
# sns.set_style("whitegrid")
#
# # First visualization: Sales Forecast Trend Over Time for Each Product
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=data_1, x='Month', y='Sales Forecast', hue='Product', marker='o')
# plt.title('Sales Forecast Trend Over Time for Each Product')
# plt.ylabel('Sales Forecast')
# plt.xticks(rotation=45)
# plt.legend(title='Product')
# plt.tight_layout()
# plt.show()
#
# output >
#
# assistant > Here's the first visualization showing the **Sales Forecast Trend Over Time** for each product. It displays how the sales forecast changes from January to May for both Product A and Product B.
#
# Next, let's create a visualization for the revenue vs. cost forecast for each product.# Second visualization: Revenue Vs. Cost Forecast for Each Product
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=data_1, x='Month', y='Revenue Forecast', hue='Product', marker='o', style='Product', dashes=False, linewidth=2)
# sns.lineplot(data=data_1, x='Month', y='Cost Forecast', hue='Product', marker='x', style='Product', dashes=[(2, 2)])
# plt.title('Revenue Vs. Cost Forecast for Each Product')
# plt.ylabel('Forecast Value')
# plt.xticks(rotation=45)
# plt.legend(title='Forecast Type', labels=['Revenue (Product A)', 'Revenue (Product B)', 'Cost (Product A)', 'Cost (Product B)'])
# plt.tight_layout()
# plt.show()
# assistant > It seems there was an issue specifying the line styles for the second plot. Let's adjust the approach and create a single plot with a different line style for revenue and cost forecasts without errors. # Correct the line style issue and plot Revenue Vs. Cost Forecast for Each Product
# plt.figure(figsize=(12, 6))
#
# # Plot revenue forecast
# sns.lineplot(data=data_1, x='Month', y='Revenue Forecast', hue='Product', marker='o', linewidth=2, style='eventtype', dashes=False)
#
# # Plot cost forecast
# sns.lineplot(data=data_1, x='Month', y='Cost Forecast', hue='Product', marker='x', linewidth=2, style='eventtype', dashes=[(2, 2)])
#
# plt.title('Revenue Vs. Cost Forecast for Each Product')
# plt.ylabel('Forecast Value ($)')
# plt.xticks(rotation=45)
# plt.legend(title='Legend', labels=['Revenue (Product A)', 'Revenue (Product B)', 'Cost (Product A)', 'Cost (Product B)'])
# plt.tight_layout()
# plt.show()
# assistant > It seems there was another misunderstanding in specifying the style. Let's simplify the plot by differentiating between revenue and cost forecasts using line colors and markers, without line style variations. I will proceed to try again.# Plot Revenue Vs. Cost Forecast for Each Product with simplified styling
# plt.figure(figsize=(12, 6))
#
# # Revenue forecast
# sns.lineplot(data=data_1, x='Month', y='Revenue Forecast', hue='Product', marker='o', linewidth=2, linestyle='-', label='Revenue')
#
# # Cost forecast
# sns.lineplot(data=data_1, x='Month', y='Cost Forecast', hue='Product', marker='x', linewidth=2, linestyle='--', label='Cost')
#
# plt.title('Revenue Vs. Cost Forecast for Each Product')
# plt.ylabel('Forecast Value')
# plt.xticks(rotation=45)
# plt.legend(title='Legend', fancybox=True, shadow=True)
# plt.tight_layout()
# plt.show()
#
# output >
#
# assistant > This visualization displays the **Revenue vs. Cost Forecast** for each product. Solid lines represent revenue forecasts, while dashed lines represent cost forecasts. Each product's revenue and cost trends are shown from January to May.
#
# Let's move on to the third visualization and compare profit forecasts between the products.# Third visualization: Profit Forecast Comparison Between Products
# plt.figure(figsize=(10, 6))
# sns.barplot(data=data_1, x='Month', y='Profit Forecast', hue='Product')
# plt.title('Profit Forecast Comparison Between Products')
# plt.ylabel('Profit Forecast')
# plt.xticks(rotation=45)
# plt.legend(title='Product')
# plt.tight_layout()
# plt.show()
#
# output >
#
# assistant > The third visualization compares the **Profit Forecast** between Product A and Product B over the months. This bar chart helps to understand which product is expected to yield more profit each month.
#
# These visualizations provide insights into the trends and forecasts for sales, revenue, costs, and profits for the two products. If you need any further analysis or modifications, feel free to ask!

# %%
# Retrieve the message object
message = client.beta.threads.messages.retrieve(
  thread_id="...",
  message_id="..."
)
# Extract the message content
message_content = message.content[0].text
annotations = message_content.annotations
citations = []
# Iterate over the annotations and add footnotes
for index, annotation in enumerate(annotations):
    # Replace the text with a footnote
    message_content.value = message_content.value.replace(annotation.text, f' [{index}]')
    # Gather citations based on annotation attributes
    if (file_citation := getattr(annotation, 'file_citation', None)):
        cited_file = client.files.retrieve(file_citation.file_id)
        citations.append(f'[{index}] {file_citation.quote} from {cited_file.filename}')
    elif (file_path := getattr(annotation, 'file_path', None)):
        cited_file = client.files.retrieve(file_path.file_id)
        citations.append(f'[{index}] Click <here> to download {cited_file.filename}')
        # Note: File download functionality not implemented above for brevity
# Add footnotes to the end of the message before displaying to user
message_content.value += '\n' + '\n'.join(citations)
